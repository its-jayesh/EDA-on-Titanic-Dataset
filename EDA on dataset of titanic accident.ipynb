# %%
import numpy as np # linear algebra
import pandas as pd # data processing

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the dataset
df=pd.read_csv('C:/Users/JAYESH/Downloads/titanic.csv')

# %%
# Shape
df.shape
# Out:
# (891, 12)

# %%
# Previewing the data
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Listing down the columns
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Few conclusions

# 1. Missing values in Age, Cabin and Embarked columns
# 2. More than 70 percent values are missing in cabin columns, will have to drop
# 3. Few columns have inappropriate data types

# %%
# Dropping cabin column

df.drop(columns=['Cabin'],inplace=True)

# %%
# Imputing missing values for age
# Strategy - mean

df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
# Imputing missing values for embarked

# finding the most appeared value in embarked column

df['Embarked'].value_counts()

# S it is

df['Embarked'].fillna('S', inplace=True)

# %%
# Want to check one more thing...

# Should I change the SibSp and Parch to categories

df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %% [markdown]
# ## Changing data type for the following cols
#
# - Survived(category)
# - PClass(category)
# - Sex(category)
# - Age(int)
# - Embarked(category)

# %%
df['Survived']=df['Survived'].astype('category')
df['Pclass']=df['Pclass'].astype('category')
df['Sex']=df['Sex'].astype('category')
df['Age']=df['Age'].astype('int')
df['Embarked']=df['Embarked'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    category
# dtypes: category(4), float64(1), int32(1), int64(3), object(2)
# memory usage: 49.4+ KB

# %%
# Five point summary
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.544332    0.523008    0.381594   32.204208
# std     257.353842   13.013778    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000   29.000000    0.000000    0.000000   14.454200
# 75%     668.500000   35.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Univariate Analysis

# Let's start with the Survived col

sns.countplot(df['Survived'])

death_percent=round((df['Survived'].value_counts().values[0]/891)*100)

print("Out of 891 {} people died in the accident".format(death_percent))
# Out:
# Out of 891 62 people died in the accident

# %%
# Pclass column

print((df['Pclass'].value_counts()/891)*100)

sns.countplot(df['Pclass'])

# Conclusion : Pclass was the most crowded class
# Out:
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: Pclass, dtype: float64
# <Axes: xlabel='count', ylabel='Pclass'>

# %%
print((df['Sex'].value_counts()/891)*100)

sns.countplot(df['Sex'])
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64
# <Axes: xlabel='count', ylabel='Sex'>

# %%
print(df['SibSp'].value_counts())

sns.countplot(df['SibSp'])
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
# <Axes: ylabel='count'>

# %%
print((df['Parch'].value_counts()/891)*100)

sns.countplot(df['Parch'])
# Out:
# 0    76.094276
# 1    13.243547
# 2     8.978676
# 5     0.561167
# 3     0.561167
# 4     0.448934
# 6     0.112233
# Name: Parch, dtype: float64
# <Axes: ylabel='count'>

# %%
print((df['Embarked'].value_counts()/891)*100)

sns.countplot(df['Embarked'])
# Out:
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: Embarked, dtype: float64
# <Axes: xlabel='count', ylabel='Embarked'>

# %%
# Age column

sns.displot(df['Age'])

print(df['Age'].skew())

print(df['Age'].kurt())
# Out:
# 0.45956263424701577
# 0.9865867453652877

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
# Just out of curiosity

print("People with age in between 60 and 70 are",df[(df['Age']>60) & (df['Age']<70)].shape[0])
print("People with age greater than 70 and 75 are",df[(df['Age']>=70) & (df['Age']<=75)].shape[0])
print("People with age greater than 75 are",df[df['Age']>75].shape[0])

print('-'*50)

print("People with age between 0 and 1",df[df['Age']<1].shape[0])
# Out:
# People with age in between 60 and 70 are 15
# People with age greater than 70 and 75 are 6
# People with age greater than 75 are 1
# --------------------------------------------------
# People with age between 0 and 1 7

# %% [markdown]
# ## Conclusion
#
# - For all practical purposes age can be cosidered as normal distribution
# - Deeper analysis is required for outlier detection

# %%
# Fare column

sns.displot(df['Fare'])

# %%
print(df['Fare'].skew())
print(df['Fare'].kurt())
# Out:
# 4.787316519674893
# 33.39814088089868

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
print("People with fare in between $200 and $300",df[(df['Fare']>200) & (df['Fare']<300)].shape[0])
print("People with fare in greater than $300",df[df['Fare']>300].shape[0])
# Out:
# People with fare in between $200 and $300 17
# People with fare in greater than $300 3

# %% [markdown]
# ## Conclusion
#
# - Highly skewed data, a lot of people had cheaper tickets
# - Outliers are there in the data

# %%
# Survival with Embarked

sns.countplot(df['Survived'], hue=df['Embarked'])

pd.crosstab(df['Embarked'], df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Embarked
# C         44.6  55.4
# Q         61.0  39.0
# S         66.1  33.9

# %%
# Survived with Age

plt.figure(figsize=(15,6))
sns.distplot(df[df['Survived']==0]['Age'])
sns.distplot(df[df['Survived']==1]['Age'])

# %%
# Survived with Fare

plt.figure(figsize=(15,6))
sns.displot(df[df['Survived']==0]['Fare'])
sns.displot(df[df['Survived']==1]['Fare'])

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\JAYESH\AppData\Local\Temp\ipykernel_24616\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
# Feature Engineering

# We will create a new column by the name of family which will be the sum of SibSp and Parch cols

df['family_size']=df['Parch'] + df['SibSp']

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                                  Name  \
# 716          717        1      1         Endres, Miss. Caroline Louise
# 570          571        1      2                    Harris, Mr. George
# 317          318        0      2                  Moraweck, Dr. Ernest
# 765          766        1      1  Hogeboom, Mrs. John C (Anna Andrews)
# 384          385        0      3                Plotcharsky, Mr. Vasil
#
#         Sex  Age  SibSp  Parch       Ticket      Fare Embarked  family_size
# 716  female   38      0      0     PC 17757  227.5250        C            0
# 570    male   62      0      0  S.W./PP 752   10.5000        S            0
# 317    male   54      0      0        29011   14.0000        S            0
# 765  female   51      1      0        13502   77.9583        S            1
# 384    male   29      0      0       349227    7.8958        S            0

# %%
# Now we will enginner a new feature by the name of family type

def family_type(number):
    if number==0:
        return "Alone"
    elif number>0 and number<=4:
        return "Medium"
    else:
        return "Large"

# %%
df['family_type']=df['family_size'].apply(family_type)

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                               Name   Sex  \
# 7              8        0      3     Palsson, Master. Gosta Leonard  male
# 48            49        0      3                Samaan, Mr. Youssef  male
# 840          841        0      3        Alhomaki, Mr. Ilmari Rudolf  male
# 494          495        0      3         Stanley, Mr. Edward Roland  male
# 149          150        0      2  Byles, Rev. Thomas Roussel Davids  male
#
#      Age  SibSp  Parch            Ticket     Fare Embarked  family_size  \
# 7      2      3      1            349909  21.0750        S            4
# 48    29      2      0              2662  21.6792        C            2
# 840   20      0      0  SOTON/O2 3101287   7.9250        S            0
# 494   21      0      0         A/4 45380   8.0500        S            0
# 149   42      0      0            244310  13.0000        S            0
#
#     family_type
# 7        Medium
# 48       Medium
# 840       Alone
# 494       Alone
# 149       Alone

# %%
# Dropping SibSp, Parch and family_size

df.drop(columns=['SibSp','Parch','family_size'],inplace=True)

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                               Name     Sex  \
# 364          365        0      3                O'Brien, Mr. Thomas    male
# 359          360        1      3  Mockler, Miss. Helen Mary "Ellie"  female
# 248          249        1      1      Beckwith, Mr. Richard Leonard    male
# 306          307        1      1            Fleming, Miss. Margaret  female
# 193          194        1      2         Navratil, Master. Michel M    male
#
#      Age  Ticket      Fare Embarked family_type
# 364   29  370365   15.5000        Q      Medium
# 359   29  330980    7.8792        Q       Alone
# 248   37   11751   52.5542        S      Medium
# 306   29   17421  110.8833        C       Alone
# 193    3  230080   26.0000        S      Medium

# %%
pd.crosstab(df['family_type'], df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived        0     1
# family_type
# Alone        69.6  30.4
# Large        85.1  14.9
# Medium       44.0  56.0

# %% [markdown]
# ## Detecting outliers
#
# ### Numerical Data
# - if the data is following normal distribution, anything beyond   3*SD - mean + 3*SD can be considered as an outlier
# - if the data does not follow normal distribution, using boxplot we can eliminate points beyond Q1 - 1.5 * IQR and Q3 + 1.5 * IQR
#
# ### Categorical data
# - If the col is highly imbalnced for eg male 10000 and female 2 then we can eliminate female

# %%
# handling outliers in age(Almost normal)

df=df[df['Age']<(df['Age'].mean() + 3 * df['Age'].std())]
df.shape
# Out:
# (884, 10)

# %%
# handling outliers from Fare column

# Finding quartiles

Q1= np.percentile(df['Fare'],25)
Q3= np.percentile(df['Fare'],75)

outlier_low=Q1 - 1.5 * (Q3 - Q1)
outlier_high=Q3 + 1.5 * (Q3 - Q1)

df=df[(df['Fare']>outlier_low) & (df['Fare']<outlier_high)]

# %%
# One hot encoding

df.sample(4)

# Cols to be transformed are Pclass, Sex, Embarked, family_type

pd.get_dummies(data=df, columns=['Pclass','Sex','Embarked','family_type'], drop_first=True)
# Out:
#      PassengerId Survived                                          Name  Age  \
# 0              1        0                       Braund, Mr. Owen Harris   22
# 2              3        1                        Heikkinen, Miss. Laina   26
# 3              4        1  Futrelle, Mrs. Jacques Heath (Lily May Peel)   35
# 4              5        0                      Allen, Mr. William Henry   35
# 5              6        0                              Moran, Mr. James   29
# ..           ...      ...                                           ...  ...
# 886          887        0                         Montvila, Rev. Juozas   27
# 887          888        1                  Graham, Miss. Margaret Edith   19
# 888          889        0      Johnston, Miss. Catherine Helen "Carrie"   29
# 889          890        1                         Behr, Mr. Karl Howell   26
# 890          891        0                           Dooley, Mr. Patrick   32
#
#                Ticket     Fare  Pclass_2  Pclass_3  Sex_male  Embarked_Q  \
# 0           A/5 21171   7.2500         0         1         1           0
# 2    STON/O2. 3101282   7.9250         0         1         0           0
# 3              113803  53.1000         0         0         0           0
# 4              373450   8.0500         0         1         1           0
# 5              330877   8.4583         0         1         1           1
# ..                ...      ...       ...       ...       ...         ...
# 886            211536  13.0000         1         0         1           0
# 887            112053  30.0000         0         0         0           0
# 888        W./C. 6607  23.4500         0         1         0           0
# 889            111369  30.0000         0         0         1           0
# 890            370376   7.7500         0         1         1           1
#
#      Embarked_S  family_type_Large  family_type_Medium
# 0             1                  0                   1
# 2             1                  0                   0
# 3             1                  0                   1
# 4             1                  0                   0
# 5             0                  0                   0
# ..          ...                ...                 ...
# 886           1                  0                   0
# 887           1                  0                   0
# 888           1                  0                   1
# 889           0                  0                   0
# 890           0                  0                   0
#
# [769 rows x 13 columns]

# %%
df=pd.get_dummies(data=df, columns=['Pclass','Sex','Embarked','family_type'], drop_first=True)

# %%
plt.figure(figsize=(15,6))
sns.heatmap(df.corr(), cmap='summer')
# Out:
# C:\Users\JAYESH\AppData\Local\Temp\ipykernel_24616\98044397.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap='summer')
# <Axes: >

# %% [markdown]
# ## Drawing Conclusions
#
# - Chance of female survival is higher than male survival
# - Travelling in Pclass 3 was deadliest
# - Somehow, people going to C survived more
# - People in the age range of 20 to 40 had a higher chance of not surviving
# - People travelling with smaller familes had a higher chance of surviving the accident in comparison to people with large families and travelling alone
